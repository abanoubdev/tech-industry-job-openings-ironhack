# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import joblib
import os

# %%
df = pd.read_csv('../DataSet/cleaned_job_data.csv')
df
# Out:
#                Job_Title    Industry  Job_Status AI_Impact_Level  \
# 0      software engineer  Healthcare  Decreasing            High
# 1      software engineer  Healthcare  Decreasing            High
# 2      software engineer  Healthcare  Decreasing            High
# 3      software engineer  Healthcare  Decreasing            High
# 4      software engineer  Healthcare  Decreasing            High
# ...                  ...         ...         ...             ...
# 28624  software engineer     Finance  Decreasing        Moderate
# 28625  software engineer     Finance  Decreasing        Moderate
# 28626  software engineer     Finance  Decreasing        Moderate
# 28627  software engineer     Finance  Decreasing        Moderate
# 28628  software engineer     Finance  Decreasing        Moderate
#
#        Median_Salary_(USD) Required_Education  Experience_Required_(Years)  \
# 0                102875.23                PhD                            5
# 1                102875.23                PhD                            5
# 2                102875.23                PhD                            5
# 3                102875.23                PhD                            5
# 4                102875.23                PhD                            5
# ...                    ...                ...                          ...
# 28624             45199.51  Bachelor’s Degree                            3
# 28625             45199.51  Bachelor’s Degree                            3
# 28626             45199.51  Bachelor’s Degree                            3
# 28627             45199.51  Bachelor’s Degree                            3
# 28628             45199.51  Bachelor’s Degree                            3
#
#        Job_Openings_(2024)  Projected_Openings_(2030)  Remote_Work_Ratio  \
# 0                     6308                       1454              36.35
# 1                     6308                       1454              36.35
# 2                     6308                       1454              36.35
# 3                     6308                       1454              36.35
# 4                     6308                       1454              36.35
# ...                    ...                        ...                ...
# 28624                 3142                        278               2.09
# 28625                 3142                        278               2.09
# 28626                 3142                        278               2.09
# 28627                 3142                        278               2.09
# 28628                 3142                        278               2.09
#
#        Automation_Risk Location  Gender_Diversity  Growth_Rate Risk_Category  \
# 0                 1.74  Germany             23.51    -0.769499           Low
# 1                 1.74  Germany             23.51    -0.769499           Low
# 2                 1.74  Germany             23.51    -0.769499           Low
# 3                 1.74  Germany             23.51    -0.769499           Low
# 4                 1.74  Germany             23.51    -0.769499           Low
# ...                ...      ...               ...          ...           ...
# 28624            70.09   Canada             70.89    -0.911521          High
# 28625            70.09   Canada             70.89    -0.911521          High
# 28626            70.09   Canada             70.89    -0.911521          High
# 28627            70.09   Canada             70.89    -0.911521          High
# 28628            70.09   Canada             70.89    -0.911521          High
#
#       Seniority  AI_Exposure_Index  Tech_Growth_Factor  \
# 0       Regular               0.39                0.68
# 1       Regular               0.16                0.57
# 2       Regular               0.61                0.67
# 3       Regular               0.32                0.52
# 4       Regular               0.06                1.17
# ...         ...                ...                 ...
# 28624   Regular               0.68                1.12
# 28625   Regular               0.21                0.60
# 28626   Regular               0.64                0.63
# 28627   Regular               0.06                1.16
# 28628   Regular               0.89                0.83
#
#        Automation_Probability_2030
# 0                             0.60
# 1                             0.56
# 2                             0.70
# 3                             0.36
# 4                             0.53
# ...                            ...
# 28624                         0.34
# 28625                         0.41
# 28626                         0.31
# 28627                         0.61
# 28628                         0.55
#
# [28629 rows x 19 columns]

# %%
df['Location'].value_counts()
# Out:
# Location
# Brazil       4785
# UK           3979
# Canada       3885
# India        3654
# Germany      3273
# USA          3186
# Australia    3016
# China        2851
# Name: count, dtype: int64

# %% [markdown]
# ## Label Encoding for categorical columns

# %%
df = pd.read_csv('../DataSet/cleaned_job_data.csv')

categorical_cols = [
    'Job_Title', 'Industry', 'Job_Status', 'Required_Education', 
    'Location', 'Risk_Category', 'Seniority', 'AI_Impact_Level'
]

encoders = {}

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

joblib.dump(encoders, '../DataSet/Encoder/label_encoders.pkl')
df.head()
# Out:
#    Job_Title  Industry  Job_Status  AI_Impact_Level  Median_Salary_(USD)  \
# 0          3         3           0                0            102875.23
# 1          3         3           0                0            102875.23
# 2          3         3           0                0            102875.23
# 3          3         3           0                0            102875.23
# 4          3         3           0                0            102875.23
#
#    Required_Education  Experience_Required_(Years)  Job_Openings_(2024)  \
# 0                   4                            5                 6308
# 1                   4                            5                 6308
# 2                   4                            5                 6308
# 3                   4                            5                 6308
# 4                   4                            5                 6308
#
#    Projected_Openings_(2030)  Remote_Work_Ratio  Automation_Risk  Location  \
# 0                       1454              36.35             1.74         4
# 1                       1454              36.35             1.74         4
# 2                       1454              36.35             1.74         4
# 3                       1454              36.35             1.74         4
# 4                       1454              36.35             1.74         4
#
#    Gender_Diversity  Growth_Rate  Risk_Category  Seniority  AI_Exposure_Index  \
# 0             23.51    -0.769499              1          0               0.39
# 1             23.51    -0.769499              1          0               0.16
# 2             23.51    -0.769499              1          0               0.61
# 3             23.51    -0.769499              1          0               0.32
# 4             23.51    -0.769499              1          0               0.06
#
#    Tech_Growth_Factor  Automation_Probability_2030
# 0                0.68                         0.60
# 1                0.57                         0.56
# 2                0.67                         0.70
# 3                0.52                         0.36
# 4                1.17                         0.53

# %% [markdown]
# ## Use StandardScaler to fit large numbers like Median_Salary_(USD) for ML model for higher predictions

# %%
import joblib

numerical_cols = [
    'Median_Salary_(USD)', 'Experience_Required_(Years)', 'Job_Openings_(2024)',
    'Projected_Openings_(2030)', 'Remote_Work_Ratio', 'Automation_Risk',
    'Gender_Diversity', 'Growth_Rate', 'AI_Exposure_Index', 
    'Tech_Growth_Factor', 'Automation_Probability_2030'
]

scaler = StandardScaler()

df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

joblib.dump(scaler, '../DataSet/Scaler/scaler.pkl')
df
# Out:
#        Job_Title  Industry  Job_Status  AI_Impact_Level  Median_Salary_(USD)  \
# 0              3         3           0                0             0.397944
# 1              3         3           0                0             0.397944
# 2              3         3           0                0             0.397944
# 3              3         3           0                0             0.397944
# 4              3         3           0                0             0.397944
# ...          ...       ...         ...              ...                  ...
# 28624          3         2           0                2            -1.344789
# 28625          3         2           0                2            -1.344789
# 28626          3         2           0                2            -1.344789
# 28627          3         2           0                2            -1.344789
# 28628          3         2           0                2            -1.344789
#
#        Required_Education  Experience_Required_(Years)  Job_Openings_(2024)  \
# 0                       4                    -0.846500             0.484342
# 1                       4                    -0.846500             0.484342
# 2                       4                    -0.846500             0.484342
# 3                       4                    -0.846500             0.484342
# 4                       4                    -0.846500             0.484342
# ...                   ...                          ...                  ...
# 28624                   1                    -1.182108            -0.615865
# 28625                   1                    -1.182108            -0.615865
# 28626                   1                    -1.182108            -0.615865
# 28627                   1                    -1.182108            -0.615865
# 28628                   1                    -1.182108            -0.615865
#
#        Projected_Openings_(2030)  Remote_Work_Ratio  Automation_Risk  \
# 0                      -1.203914          -0.495603        -1.479939
# 1                      -1.203914          -0.495603        -1.479939
# 2                      -1.203914          -0.495603        -1.479939
# 3                      -1.203914          -0.495603        -1.479939
# 4                      -1.203914          -0.495603        -1.479939
# ...                          ...                ...              ...
# 28624                  -1.608389          -1.704488         0.849130
# 28625                  -1.608389          -1.704488         0.849130
# 28626                  -1.608389          -1.704488         0.849130
# 28627                  -1.608389          -1.704488         0.849130
# 28628                  -1.608389          -1.704488         0.849130
#
#        Location  Gender_Diversity  Growth_Rate  Risk_Category  Seniority  \
# 0             4         -1.510780    -0.344427              1          0
# 1             4         -1.510780    -0.344427              1          0
# 2             4         -1.510780    -0.344427              1          0
# 3             4         -1.510780    -0.344427              1          0
# 4             4         -1.510780    -0.344427              1          0
# ...         ...               ...          ...            ...        ...
# 28624         2          1.191724    -0.362334              0          0
# 28625         2          1.191724    -0.362334              0          0
# 28626         2          1.191724    -0.362334              0          0
# 28627         2          1.191724    -0.362334              0          0
# 28628         2          1.191724    -0.362334              0          0
#
#        AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030
# 0              -0.438781           -1.071137                     0.829182
# 1              -1.244947           -1.454739                     0.479884
# 2               0.332335           -1.106010                     1.702427
# 3              -0.684136           -1.629104                    -1.266606
# 4              -1.595454            0.637635                     0.217910
# ...                  ...                 ...                          ...
# 28624           0.577690            0.463270                    -1.441255
# 28625          -1.069694           -1.350121                    -0.829984
# 28626           0.437487           -1.245502                    -1.703229
# 28627          -1.595454            0.602762                     0.916506
# 28628           1.313755           -0.548044                     0.392559
#
# [28629 rows x 19 columns]

# %%
is_high_encoded_val = encoders['AI_Impact_Level'].transform(['High'])[0]

df['Is_High_Risk'] = (df['AI_Impact_Level'] == is_high_encoded_val).astype(int)

print("Feature Engineering complete. Target column is now 'Is_High_Risk'.")
print("High Risk Jobs:", df['Is_High_Risk'].sum())
print("Total Jobs:", len(df))
# Out:
# Feature Engineering complete. Target column is now 'Is_High_Risk'.
# High Risk Jobs: 9691
# Total Jobs: 28629

# %%
df
# Out:
#        Job_Title  Industry  Job_Status  AI_Impact_Level  Median_Salary_(USD)  \
# 0              3         3           0                0             0.397944
# 1              3         3           0                0             0.397944
# 2              3         3           0                0             0.397944
# 3              3         3           0                0             0.397944
# 4              3         3           0                0             0.397944
# ...          ...       ...         ...              ...                  ...
# 28624          3         2           0                2            -1.344789
# 28625          3         2           0                2            -1.344789
# 28626          3         2           0                2            -1.344789
# 28627          3         2           0                2            -1.344789
# 28628          3         2           0                2            -1.344789
#
#        Required_Education  Experience_Required_(Years)  Job_Openings_(2024)  \
# 0                       4                    -0.846500             0.484342
# 1                       4                    -0.846500             0.484342
# 2                       4                    -0.846500             0.484342
# 3                       4                    -0.846500             0.484342
# 4                       4                    -0.846500             0.484342
# ...                   ...                          ...                  ...
# 28624                   1                    -1.182108            -0.615865
# 28625                   1                    -1.182108            -0.615865
# 28626                   1                    -1.182108            -0.615865
# 28627                   1                    -1.182108            -0.615865
# 28628                   1                    -1.182108            -0.615865
#
#        Projected_Openings_(2030)  Remote_Work_Ratio  Automation_Risk  \
# 0                      -1.203914          -0.495603        -1.479939
# 1                      -1.203914          -0.495603        -1.479939
# 2                      -1.203914          -0.495603        -1.479939
# 3                      -1.203914          -0.495603        -1.479939
# 4                      -1.203914          -0.495603        -1.479939
# ...                          ...                ...              ...
# 28624                  -1.608389          -1.704488         0.849130
# 28625                  -1.608389          -1.704488         0.849130
# 28626                  -1.608389          -1.704488         0.849130
# 28627                  -1.608389          -1.704488         0.849130
# 28628                  -1.608389          -1.704488         0.849130
#
#        Location  Gender_Diversity  Growth_Rate  Risk_Category  Seniority  \
# 0             4         -1.510780    -0.344427              1          0
# 1             4         -1.510780    -0.344427              1          0
# 2             4         -1.510780    -0.344427              1          0
# 3             4         -1.510780    -0.344427              1          0
# 4             4         -1.510780    -0.344427              1          0
# ...         ...               ...          ...            ...        ...
# 28624         2          1.191724    -0.362334              0          0
# 28625         2          1.191724    -0.362334              0          0
# 28626         2          1.191724    -0.362334              0          0
# 28627         2          1.191724    -0.362334              0          0
# 28628         2          1.191724    -0.362334              0          0
#
#        AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0              -0.438781           -1.071137                     0.829182
# 1              -1.244947           -1.454739                     0.479884
# 2               0.332335           -1.106010                     1.702427
# 3              -0.684136           -1.629104                    -1.266606
# 4              -1.595454            0.637635                     0.217910
# ...                  ...                 ...                          ...
# 28624           0.577690            0.463270                    -1.441255
# 28625          -1.069694           -1.350121                    -0.829984
# 28626           0.437487           -1.245502                    -1.703229
# 28627          -1.595454            0.602762                     0.916506
# 28628           1.313755           -0.548044                     0.392559
#
#        Is_High_Risk
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 28624             0
# 28625             0
# 28626             0
# 28627             0
# 28628             0
#
# [28629 rows x 20 columns]

# %%
df.to_csv('../DataSet/ml_ready_data.csv', index=False)

print("Data successfully saved to DataSet/ml_ready_data.csv!")
# Out:
# Data successfully saved to DataSet/ml_ready_data.csv!
